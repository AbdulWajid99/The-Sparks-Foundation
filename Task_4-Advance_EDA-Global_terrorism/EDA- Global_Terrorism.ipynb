# %% [markdown]
# ## Created by : Abdul Wajid

# %% [markdown]
#  ## Exploratory Data Analysis - Global Terrorism

# %% [markdown]
# https://www.linkedin.com/feed/update/urn:li:ugcPost:6845286424628084737?commentUrn=urn%3Ali%3Acomment%3A%28ugcPost%3A6845286424628084737%2C6845357799938019328%29

# %%
#  Importing Required Libraries

import pandas as pd  #  
import numpy as np

import matplotlib.pyplot as plt
import geopandas
from geopandas import read_file
import seaborn as sns
#GeoPandas

# %%
pd.set_option('display.max_columns',50)
pd.set_option('display.width',1000)  #  All col in single row
pd.set_option('display.max_rows',50)

# %%
df = pd.read_csv("C:\\Users\\realm\\Downloads\\Data-Global_terrorism\\dataset.csv",encoding='latin1')
df.head()
# Out:
# D:\Softwares\Anaconda3\envs\ML\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country         country_txt  region                   region_txt provstate           city   latitude   longitude  specificity  vicinity location summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  ...  nhostkid  nhostkidus  nhours  ndays divert  kidhijcountry ransom  ransomamt ransomamtus  ransompaid ransompaidus  ransomnote hostkidoutcome hostkidoutcome_txt nreleased  addnotes scite1  scite2 scite3  dbsource INT_LOG INT_IDEO INT_MISC  INT_ANY related
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# From This we get some overall information eg. from iyear col min value is 1970 nd max is 2017 so this data is from timeperiod 1970-2017,

# %%
print("Pakistan" in df['country_txt'].unique())
# Out:
# True

# %%
# Out:
# 181691

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')
sns.countplot(x='nkill',data=df)
# Out:
# <AxesSubplot:xlabel='nkill', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='nkill', data=df, palette='RdBu_r') #hue='iyear',
# Out:
# <AxesSubplot:xlabel='nkill', ylabel='count'>

# %%
df.columns[121]
# Out:
# 'ransomnote'

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
countries = df['country_txt']
countries

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-12-21cf0a24543a> in <module>
# ----> 1 world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
#
# D:\Softwares\Anaconda3\envs\ML\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     201                 )
#     202
# --> 203             return GeoDataFrame.from_features(
#     204                 f_filt, crs=crs, columns=columns + ["geometry"]
#     205             )
#
# D:\Softwares\Anaconda3\envs\ML\lib\site-packages\geopandas\geodataframe.py in from_features(cls, features, crs, columns)
#     585             row.update(feature["properties"])
#     586             rows.append(row)
# --> 587         return GeoDataFrame(rows, columns=columns, crs=crs)
#     588
#     589     @classmethod
#
# ...

# %%
ax = df.plot(column='HR60', scheme='BoxPlot', \
             cmap='BuPu', legend=True,
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5),
                         'interval': True})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-359600dd93f5> in <module>
# ----> 1 ax = df.plot(column='HR60', scheme='BoxPlot', \
#       2              cmap='BuPu', legend=True,
#       3              legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5),
#       4                          'interval': True})
#
# D:\Softwares\Anaconda3\envs\ML\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# D:\Softwares\Anaconda3\envs\ML\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
a = ['iyear', 'country','latitude','longitude']

for i in a:
    print(df[a].isnull().count())
    print(df[a])
# Out:
# iyear        181691
# country      181691
# latitude     181691
# longitude    181691
# dtype: int64
#         iyear  country   latitude   longitude
# 0        1970       58  18.456792  -69.951164
# 1        1970      130  19.371887  -99.086624
# 2        1970      160  15.478598  120.599741
# 3        1970       78  37.997490   23.762728
# 4        1970      101  33.580412  130.396361
# ...       ...      ...        ...         ...
# 181686   2017      182   2.359673   45.385034
# 181687   2017      200  35.407278   35.942679
# 181688   2017      160   6.900742  124.437908
# 181689   2017       92  24.798346   93.940430
# 181690   2017      160   7.209594  124.241966
#
# [181691 rows x 4 columns]
# iyear        181691
# country      181691
# latitude     181691
# longitude    181691
# dtype: int64
#         iyear  country   latitude   longitude
# 0        1970       58  18.456792  -69.951164
# 1        1970      130  19.371887  -99.086624
# ...

# %%
df.isnull().count()
# Out:
# eventid       181691
# iyear         181691
# imonth        181691
# iday          181691
# approxdate    181691
#                ...
# INT_LOG       181691
# INT_IDEO      181691
# INT_MISC      181691
# INT_ANY       181691
# related       181691
# Length: 135, dtype: int64

# %%
for i in range(len(df.columns)):
    print(df.columns[i])
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %%
df['country_txt'].unique()
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
# ...

# %%
plt.bar(height = '11', x = df["country_txt"].all(), y = ["country_txt"])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-59-433673fa6b0f> in <module>
# ----> 1 plt.bar(height = '11', x = df["country_txt"].all(), y = ["country_txt"])
#
# D:\Softwares\Anaconda3\envs\ML\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# D:\Softwares\Anaconda3\envs\ML\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
# ...
